# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = {
    'year': ['2020','2021','2022','2023','2024'],
    'Pigeons': [33,52,26,40,38],
    'Sparrows': [54,48,66,59,61],
    'others': [104,98,88,92,101]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    year  Pigeons  Sparrows  others
# 0  2020       33        54     104
# 1  2021       52        48      98
# 2  2022       26        66      88
# 3  2023       40        59      92
# 4  2024       38        61     101

# %%
df['som'] = df['Pigeons'] + df['Sparrows'] + df["others"]
plt.figure()
plt.plot(df['year'],df['Pigeons'], marker = 'o', label ='Pigeons', linestyle ='solid', color ='blue' )
plt.plot(df['year'],df['Sparrows'], marker ='>', markeredgecolor = 'red', label ='Sparrows', linestyle='dotted', color='green')
plt.plot(df['year'],df['others'],marker='o', label = 'others', markeredgecolor ='orange', color ='orange', linestyle= 'dashed')
plt.bar(df['year'],df['som'], width = 0.4, color ='purple', label = 'totaal')
plt.title("Aantal vogels over de jaren heen")
plt.xlabel("Jaar")
plt.ylabel("Aantal Vogels")
plt.legend()

# %%
plt.figure()
plt.bar(df['year'],df['Pigeons'],color ='blue', label= 'Pigeons')
plt.bar(df['year'],df['Sparrows'],bottom =df['Pigeons'],color='red', label='Sparrows')
plt.bar(df['year'],df['others'],bottom =df['Sparrows']+df['Pigeons'],color='orange', label ='Other Birds')
plt.title("Aantal vogels over de jaren heen")
plt.xlabel("Jaar")
plt.ylabel("Aantal Vogels")
plt.legend()
